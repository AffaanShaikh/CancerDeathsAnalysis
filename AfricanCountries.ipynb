# %%
import pandas as pd

# %%
df = pd.read_csv(r"X:\CancerAnalysis\list-african-countries-dependent-territory-286j.csv")
df
# Out:
#                                                   SNo  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   1
# ..                                                ...
# 62                                                NaN
# 63                                                NaN
# 64  For other more formats kindly visit www.downlo...
# 65                                                NaN
# 66  Original source : en.wikipedia.org/wiki/List_o...
#
#                      Country    July 1, 2013  % of   Average    Average.1  \
# 0   (or dependent territory)      projection  pop.  relative     absolute
# 1                        NaN             NaN   NaN    annual       annual
# 2                        NaN             NaN   NaN    growth       growth
# ...

# %%
#getting names of all African countries from a csv file in a list format
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df.fillna('', inplace=True)
df = df.drop_duplicates()

# %%
df['Country'].tolist()
# Out:
# ['(or dependent territory)',
#  '',
#  '',
#  '',
#  'Nigeria',
#  'Ethiopia',
#  'Egypt',
#  'Democratic Republic of the Congo',
#  'South Africa',
#  'Tanzania',
#  'Kenya',
#  'Algeria',
#  'Uganda',
#  'Sudan',
#  'Morocco',
#  'Ghana',
#  'Mozambique',
#  'Ivory Coast',
#  'Madagascar',
#  'Angola',
#  'Cameroon',
#  'Niger',
#  'Burkina Faso',
#  'Mali',
#  'Malawi',
#  'Zambia',
#  'Senegal',
#  'Zimbabwe',
#  'Chad',
#  'Guinea',
#  'Tunisia',
#  'Rwanda',
#  'South Sudan',
#  'Benin',
#  'Somalia',
#  'Burundi',
#  'Togo',
#  'Libya',
#  'Sierra Leone',
#  'Central African Republic',
#  'Eritrea',
#  'Republic of the Congo',
#  'Liberia',
#  'Mauritania',
#  'Gabon',
#  'Namibia',
#  'Botswana',
#  'Lesotho',
#  'Equatorial Guinea',
#  'Gambia',
#  'Guinea-Bissau',
#  'Mauritius',
#  'Swaziland',
#  'Djibouti',
#  'Reunion (France)',
#  'Comoros',
#  'Western Sahara',
#  'Cape Verde',
#  'Mayotte (France)',
#  'Sao Tome and Principe',
#  'Seychelles',
# ...
